# %%
import pandas as pd
from common import utils

# %%
df = pd.read_parquet(utils.find_project_root() / "data" / "raw" / "stage1_2.parquet")

# %%
df
# Out:
#                                                title  \
# 0                1. Once Upon a Time... in Hollywood
# 1   2. Mission: Impossible - Dead Reckoning Part One
# 2                            3. John Wick: Chapter 4
# 3                               4. The Fifth Element
# 4                                        5. Watchmen
# ..                                               ...
# 65                                    66. Home Alone
# 66                                   67. Blue Velvet
# 67                       68. When Harry Met Sally...
# 68                    69. O Brother, Where Art Thou?
# 69                                70. A Few Good Men
#
#                                                   url metacritic_score rating  \
# 0   https://www.imdb.com/title/tt7131622/?ref_=sr_t_1               84      R
# 1   https://www.imdb.com/title/tt9603212/?ref_=sr_t_2               81  PG-13
# 2   https://www.imdb.com/title/tt10366206/?ref_=sr...               78      R
# 3   https://www.imdb.com/title/tt0119116/?ref_=sr_t_4               52  PG-13
# 4   https://www.imdb.com/title/tt0409459/?ref_=sr_t_5               56      R
# ..                                                ...              ...    ...
# 65  https://www.imdb.com/title/tt0099785/?ref_=sr_...               63     PG
# 66  https://www.imdb.com/title/tt0090756/?ref_=sr_...               75      R
# 67  https://www.imdb.com/title/tt0098635/?ref_=sr_...               76      R
# 68  https://www.imdb.com/title/tt0190590/?ref_=sr_...               69  PG-13
# 69  https://www.imdb.com/title/tt0104257/?ref_=sr_...               62      R
#
#     year duration rating_stars   voters  \
# 0   2019   2h 41m          7.6   (930K)
# 1   2023   2h 43m          7.6   (313K)
# 2   2023   2h 49m          7.6   (394K)
# 3   1997    2h 6m          7.6   (534K)
# 4   2009   2h 42m          7.6   (604K)
# ..   ...      ...          ...      ...
# 65  1990   1h 43m          7.7   (707K)
# 66  1986       2h          7.7   (237K)
# 67  1989   1h 35m          7.7   (260K)
# 68  2000   1h 47m          7.7   (345K)
# 69  1992   2h 18m          7.7   (308K)
#
#                                           description  \
# 0   As Hollywood's Golden Age is winding down duri...
# 1   Ethan Hunt and his IMF team must track down a ...
# 2   John Wick uncovers a path to defeating The Hig...
# 3   In the colorful future, cabdriver Korben Dalla...
# 4   In a version of 1985 where superheroes exist, ...
# ..                                                ...
# 65  An eight-year-old troublemaker, mistakenly lef...
# 66  The discovery of a severed human ear found in ...
# 67  Harry and Sally have known each other for year...
# 68  In the deep south during the 1930s, three esca...
# 69  A military lawyer intends to prove that two US...
#
#                    director  ...            awards_and_nominations  \
# 0       [Quentin Tarantino]  ...  146 wins & 377 nominations total
# 1   [Christopher McQuarrie]  ...    18 wins & 68 nominations total
# 2          [Chad Stahelski]  ...    38 wins & 51 nominations total
# 3              [Luc Besson]  ...    10 wins & 39 nominations total
# 4             [Zack Snyder]  ...    12 wins & 24 nominations total
# ..                      ...  ...                               ...
# 65         [Chris Columbus]  ...     12 wins & 7 nominations total
# 66            [David Lynch]  ...    18 wins & 18 nominations total
# 67             [Rob Reiner]  ...     6 wins & 19 nominations total
# 68  [Joel Coen, Ethan Coen]  ...     8 wins & 38 nominations total
# 69             [Rob Reiner]  ...    10 wins & 30 nominations total
#
#                                                  cast  \
# 0   [Leonardo DiCaprio, Brad Pitt, Margot Robbie, ...
# 1   [Tom Cruise, Hayley Atwell, Ving Rhames, Simon...
# 2   [Keanu Reeves, Laurence Fishburne, George Geor...
# 3   [Bruce Willis, Milla Jovovich, Gary Oldman, Ia...
# 4   [Jackie Earle Haley, Patrick Wilson, Carla Gug...
# ..                                                ...
# 65  [Macaulay Culkin, Joe Pesci, Daniel Stern, Joh...
# 66  [Isabella Rossellini, Kyle MacLachlan, Dennis ...
# 67  [Billy Crystal, Meg Ryan, Carrie Fisher, Bruno...
# 68  [George Clooney, John Turturro, Tim Blake Nels...
# 69  [Tom Cruise, Jack Nicholson, Demi Moore, Kevin...
#
#                                            box_office aspect_ratio  \
# 0   {'Budget': '$90,000,000 (estimated)', 'Gross U...     2.39 : 1
# 1   {'Budget': '$291,000,000 (estimated)', 'Gross ...     2.39 : 1
# 2   {'Budget': '$100,000,000 (estimated)', 'Gross ...     2.39 : 1
# 3   {'Budget': 'FRF 75,210,000 (estimated)', 'Gros...     2.39 : 1
# 4   {'Budget': '$130,000,000 (estimated)', 'Gross ...     2.39 : 1
# ..                                                ...          ...
# 65  {'Budget': '$18,000,000 (estimated)', 'Gross U...
# 66  {'Budget': '$6,000,000 (estimated)', 'Gross US...     2.35 : 1
# 67  {'Budget': '$16,000,000 (estimated)', 'Gross U...     1.85 : 1
# 68  {'Budget': '$26,000,000 (estimated)', 'Gross U...     2.39 : 1
# 69  {'Budget': '$41,000,000 (estimated)', 'Gross U...     2.35 : 1
#
#                                   countries  \
# 0    [United States, United Kingdom, China]
# 1                           [United States]
# 2                  [United States, Germany]
# 3                  [France, United Kingdom]
# 4                           [United States]
# ..                                      ...
# 65                          [United States]
# 66                          [United States]
# 67                          [United States]
# 68  [United Kingdom, France, United States]
# 69                          [United States]
#
#                                             languages  \
# 0                 [English, Italian, Spanish, German]
# 1                 [English, Italian, Russian, French]
# 2   [English, Japanese, Russian, French, Spanish, ...
# 3   [English, Swedish, German, Arabic, Egyptian (A...
# 4                                           [English]
# ..                                                ...
# 65                                  [English, French]
# 66                                          [English]
# 67                                          [English]
# 68                                          [English]
# 69                                  [English, French]
#
#                                  production_companies  \
# 0   [Columbia Pictures, Bona Film Group, Heyday Fi...
# 1   [Paramount Pictures, Skydance Media, TC Produc...
# 2   [Lionsgate, Thunder Road Pictures, 87Eleven En...
# 3                         [Gaumont, Pinewood Studios]
# 4   [Warner Bros., Paramount Pictures, Legendary E...
# ..                                                ...
# 65      [Twentieth Century Fox, Hughes Entertainment]
# 66          [De Laurentiis Entertainment Group (DEG)]
# 67  [Castle Rock Entertainment, Nelson Entertainme...
# 68  [Touchstone Pictures, Universal Pictures, Stud...
# 69  [Columbia Pictures, Castle Rock Entertainment,...
#
#                          release_date  \
# 0       July 26, 2019 (United States)
# 1       July 12, 2023 (United States)
# 2      March 24, 2023 (United States)
# 3         May 9, 1997 (United States)
# 4       March 6, 2009 (United States)
# ..                                ...
# 65  November 16, 1990 (United States)
# 66           October 23, 1986 (Italy)
# 67      July 21, 1989 (United States)
# 68   February 2, 2001 (United States)
# 69  December 11, 1992 (United States)
#
#                                        comentarios_ia  \
# 0   [Authentic emotion positive sentiment, Charact...
# 1   [Action sequences positive sentiment, Sound de...
# 2   [Action sequences positive sentiment, Cinemato...
# 3                                                  []
# 4   [Ambitious positive sentiment, Cinematography ...
# ..                                                ...
# 65                                                 []
# 66                                                 []
# 67                                                 []
# 68                                                 []
# 69                                                 []
#
#                                            ai_summary
# 0   Reviewers say 'Once Upon a Time in Hollywood' ...
# 1   Reviewers say 'Mission: Impossible - Dead Reck...
# 2   Reviewers say 'John Wick: Chapter 4' is lauded...
# 3
# 4   Reviewers say 'Watchmen' is acclaimed for its ...
# ..                                                ...
# 65
# 66
# 67
# 68
# 69
#
# [70 rows x 25 columns]

# %%
df["title"] = df["title"].replace("^[^.]+. ", "", regex=True)
df.head()
# Out:
#                                            title  \
# 0               Once Upon a Time... in Hollywood
# 1  Mission: Impossible - Dead Reckoning Part One
# 2                           John Wick: Chapter 4
# 3                              The Fifth Element
# 4                                       Watchmen
#
#                                                  url metacritic_score rating  \
# 0  https://www.imdb.com/title/tt7131622/?ref_=sr_t_1               84      R
# 1  https://www.imdb.com/title/tt9603212/?ref_=sr_t_2               81  PG-13
# 2  https://www.imdb.com/title/tt10366206/?ref_=sr...               78      R
# 3  https://www.imdb.com/title/tt0119116/?ref_=sr_t_4               52  PG-13
# 4  https://www.imdb.com/title/tt0409459/?ref_=sr_t_5               56      R
#
#    year duration rating_stars   voters  \
# 0  2019   2h 41m          7.6   (930K)
# 1  2023   2h 43m          7.6   (313K)
# 2  2023   2h 49m          7.6   (394K)
# 3  1997    2h 6m          7.6   (534K)
# 4  2009   2h 42m          7.6   (604K)
#
#                                          description                 director  \
# 0  As Hollywood's Golden Age is winding down duri...      [Quentin Tarantino]
# 1  Ethan Hunt and his IMF team must track down a ...  [Christopher McQuarrie]
# 2  John Wick uncovers a path to defeating The Hig...         [Chad Stahelski]
# 3  In the colorful future, cabdriver Korben Dalla...             [Luc Besson]
# 4  In a version of 1985 where superheroes exist, ...            [Zack Snyder]
#
#    ...            awards_and_nominations  \
# 0  ...  146 wins & 377 nominations total
# 1  ...    18 wins & 68 nominations total
# 2  ...    38 wins & 51 nominations total
# 3  ...    10 wins & 39 nominations total
# 4  ...    12 wins & 24 nominations total
#
#                                                 cast  \
# 0  [Leonardo DiCaprio, Brad Pitt, Margot Robbie, ...
# 1  [Tom Cruise, Hayley Atwell, Ving Rhames, Simon...
# 2  [Keanu Reeves, Laurence Fishburne, George Geor...
# 3  [Bruce Willis, Milla Jovovich, Gary Oldman, Ia...
# 4  [Jackie Earle Haley, Patrick Wilson, Carla Gug...
#
#                                           box_office aspect_ratio  \
# 0  {'Budget': '$90,000,000 (estimated)', 'Gross U...     2.39 : 1
# 1  {'Budget': '$291,000,000 (estimated)', 'Gross ...     2.39 : 1
# 2  {'Budget': '$100,000,000 (estimated)', 'Gross ...     2.39 : 1
# 3  {'Budget': 'FRF 75,210,000 (estimated)', 'Gros...     2.39 : 1
# 4  {'Budget': '$130,000,000 (estimated)', 'Gross ...     2.39 : 1
#
#                                 countries  \
# 0  [United States, United Kingdom, China]
# 1                         [United States]
# 2                [United States, Germany]
# 3                [France, United Kingdom]
# 4                         [United States]
#
#                                            languages  \
# 0                [English, Italian, Spanish, German]
# 1                [English, Italian, Russian, French]
# 2  [English, Japanese, Russian, French, Spanish, ...
# 3  [English, Swedish, German, Arabic, Egyptian (A...
# 4                                          [English]
#
#                                 production_companies  \
# 0  [Columbia Pictures, Bona Film Group, Heyday Fi...
# 1  [Paramount Pictures, Skydance Media, TC Produc...
# 2  [Lionsgate, Thunder Road Pictures, 87Eleven En...
# 3                        [Gaumont, Pinewood Studios]
# 4  [Warner Bros., Paramount Pictures, Legendary E...
#
#                      release_date  \
# 0   July 26, 2019 (United States)
# 1   July 12, 2023 (United States)
# 2  March 24, 2023 (United States)
# 3     May 9, 1997 (United States)
# 4   March 6, 2009 (United States)
#
#                                       comentarios_ia  \
# 0  [Authentic emotion positive sentiment, Charact...
# 1  [Action sequences positive sentiment, Sound de...
# 2  [Action sequences positive sentiment, Cinemato...
# 3                                                 []
# 4  [Ambitious positive sentiment, Cinematography ...
#
#                                           ai_summary
# 0  Reviewers say 'Once Upon a Time in Hollywood' ...
# 1  Reviewers say 'Mission: Impossible - Dead Reck...
# 2  Reviewers say 'John Wick: Chapter 4' is lauded...
# 3
# 4  Reviewers say 'Watchmen' is acclaimed for its ...
#
# [5 rows x 25 columns]

# %%
def parse_duration(value: str) -> int:
    mins = 0
    for component in value.split(" "):
        if component.endswith("h"):
            hours = int(component[:-1])
            mins += hours * 60
        elif component.endswith("m"):
            minutes = int(component[:-1])
            mins += minutes

    return mins


df["duration_mins"] = df["duration"].apply(parse_duration)
df.head()
# Out:
#                                            title  \
# 0               Once Upon a Time... in Hollywood
# 1  Mission: Impossible - Dead Reckoning Part One
# 2                           John Wick: Chapter 4
# 3                              The Fifth Element
# 4                                       Watchmen
#
#                                                  url metacritic_score rating  \
# 0  https://www.imdb.com/title/tt7131622/?ref_=sr_t_1               84      R
# 1  https://www.imdb.com/title/tt9603212/?ref_=sr_t_2               81  PG-13
# 2  https://www.imdb.com/title/tt10366206/?ref_=sr...               78      R
# 3  https://www.imdb.com/title/tt0119116/?ref_=sr_t_4               52  PG-13
# 4  https://www.imdb.com/title/tt0409459/?ref_=sr_t_5               56      R
#
#    year duration rating_stars   voters  \
# 0  2019   2h 41m          7.6   (930K)
# 1  2023   2h 43m          7.6   (313K)
# 2  2023   2h 49m          7.6   (394K)
# 3  1997    2h 6m          7.6   (534K)
# 4  2009   2h 42m          7.6   (604K)
#
#                                          description                 director  \
# 0  As Hollywood's Golden Age is winding down duri...      [Quentin Tarantino]
# 1  Ethan Hunt and his IMF team must track down a ...  [Christopher McQuarrie]
# 2  John Wick uncovers a path to defeating The Hig...         [Chad Stahelski]
# 3  In the colorful future, cabdriver Korben Dalla...             [Luc Besson]
# 4  In a version of 1985 where superheroes exist, ...            [Zack Snyder]
#
#    ...                                               cast  \
# 0  ...  [Leonardo DiCaprio, Brad Pitt, Margot Robbie, ...
# 1  ...  [Tom Cruise, Hayley Atwell, Ving Rhames, Simon...
# 2  ...  [Keanu Reeves, Laurence Fishburne, George Geor...
# 3  ...  [Bruce Willis, Milla Jovovich, Gary Oldman, Ia...
# 4  ...  [Jackie Earle Haley, Patrick Wilson, Carla Gug...
#
#                                           box_office aspect_ratio  \
# 0  {'Budget': '$90,000,000 (estimated)', 'Gross U...     2.39 : 1
# 1  {'Budget': '$291,000,000 (estimated)', 'Gross ...     2.39 : 1
# 2  {'Budget': '$100,000,000 (estimated)', 'Gross ...     2.39 : 1
# 3  {'Budget': 'FRF 75,210,000 (estimated)', 'Gros...     2.39 : 1
# 4  {'Budget': '$130,000,000 (estimated)', 'Gross ...     2.39 : 1
#
#                                 countries  \
# 0  [United States, United Kingdom, China]
# 1                         [United States]
# 2                [United States, Germany]
# 3                [France, United Kingdom]
# 4                         [United States]
#
#                                            languages  \
# 0                [English, Italian, Spanish, German]
# 1                [English, Italian, Russian, French]
# 2  [English, Japanese, Russian, French, Spanish, ...
# 3  [English, Swedish, German, Arabic, Egyptian (A...
# 4                                          [English]
#
#                                 production_companies  \
# 0  [Columbia Pictures, Bona Film Group, Heyday Fi...
# 1  [Paramount Pictures, Skydance Media, TC Produc...
# 2  [Lionsgate, Thunder Road Pictures, 87Eleven En...
# 3                        [Gaumont, Pinewood Studios]
# 4  [Warner Bros., Paramount Pictures, Legendary E...
#
#                      release_date  \
# 0   July 26, 2019 (United States)
# 1   July 12, 2023 (United States)
# 2  March 24, 2023 (United States)
# 3     May 9, 1997 (United States)
# 4   March 6, 2009 (United States)
#
#                                       comentarios_ia  \
# 0  [Authentic emotion positive sentiment, Charact...
# 1  [Action sequences positive sentiment, Sound de...
# 2  [Action sequences positive sentiment, Cinemato...
# 3                                                 []
# 4  [Ambitious positive sentiment, Cinematography ...
#
#                                           ai_summary duration_mins
# 0  Reviewers say 'Once Upon a Time in Hollywood' ...           161
# 1  Reviewers say 'Mission: Impossible - Dead Reck...           163
# 2  Reviewers say 'John Wick: Chapter 4' is lauded...           169
# 3                                                              126
# 4  Reviewers say 'Watchmen' is acclaimed for its ...           162
#
# [5 rows x 26 columns]

# %%
df["budget"] = df["box_office"].map(lambda x: x.get("Budget", 0))
df["gross_world"] = df["box_office"].map(lambda x: x.get("Gross worldwide", 0))
df["gross_usa_canada"] = df["box_office"].map(lambda x: x.get("Gross US & Canada", 0))
df["opening_weekend_usa_canada"] = df["box_office"].map(lambda x: x.get("Opening weekend US & Canada", None))

df
# Out:
#                                             title  \
# 0                Once Upon a Time... in Hollywood
# 1   Mission: Impossible - Dead Reckoning Part One
# 2                            John Wick: Chapter 4
# 3                               The Fifth Element
# 4                                        Watchmen
# ..                                            ...
# 65                                     Home Alone
# 66                                    Blue Velvet
# 67                        When Harry Met Sally...
# 68                     O Brother, Where Art Thou?
# 69                                 A Few Good Men
#
#                                                   url metacritic_score rating  \
# 0   https://www.imdb.com/title/tt7131622/?ref_=sr_t_1               84      R
# 1   https://www.imdb.com/title/tt9603212/?ref_=sr_t_2               81  PG-13
# 2   https://www.imdb.com/title/tt10366206/?ref_=sr...               78      R
# 3   https://www.imdb.com/title/tt0119116/?ref_=sr_t_4               52  PG-13
# 4   https://www.imdb.com/title/tt0409459/?ref_=sr_t_5               56      R
# ..                                                ...              ...    ...
# 65  https://www.imdb.com/title/tt0099785/?ref_=sr_...               63     PG
# 66  https://www.imdb.com/title/tt0090756/?ref_=sr_...               75      R
# 67  https://www.imdb.com/title/tt0098635/?ref_=sr_...               76      R
# 68  https://www.imdb.com/title/tt0190590/?ref_=sr_...               69  PG-13
# 69  https://www.imdb.com/title/tt0104257/?ref_=sr_...               62      R
#
#     year duration rating_stars   voters  \
# 0   2019   2h 41m          7.6   (930K)
# 1   2023   2h 43m          7.6   (313K)
# 2   2023   2h 49m          7.6   (394K)
# 3   1997    2h 6m          7.6   (534K)
# 4   2009   2h 42m          7.6   (604K)
# ..   ...      ...          ...      ...
# 65  1990   1h 43m          7.7   (707K)
# 66  1986       2h          7.7   (237K)
# 67  1989   1h 35m          7.7   (260K)
# 68  2000   1h 47m          7.7   (345K)
# 69  1992   2h 18m          7.7   (308K)
#
#                                           description  \
# 0   As Hollywood's Golden Age is winding down duri...
# 1   Ethan Hunt and his IMF team must track down a ...
# 2   John Wick uncovers a path to defeating The Hig...
# 3   In the colorful future, cabdriver Korben Dalla...
# 4   In a version of 1985 where superheroes exist, ...
# ..                                                ...
# 65  An eight-year-old troublemaker, mistakenly lef...
# 66  The discovery of a severed human ear found in ...
# 67  Harry and Sally have known each other for year...
# 68  In the deep south during the 1930s, three esca...
# 69  A military lawyer intends to prove that two US...
#
#                    director  ...  \
# 0       [Quentin Tarantino]  ...
# 1   [Christopher McQuarrie]  ...
# 2          [Chad Stahelski]  ...
# 3              [Luc Besson]  ...
# 4             [Zack Snyder]  ...
# ..                      ...  ...
# 65         [Chris Columbus]  ...
# 66            [David Lynch]  ...
# 67             [Rob Reiner]  ...
# 68  [Joel Coen, Ethan Coen]  ...
# 69             [Rob Reiner]  ...
#
#                                             languages  \
# 0                 [English, Italian, Spanish, German]
# 1                 [English, Italian, Russian, French]
# 2   [English, Japanese, Russian, French, Spanish, ...
# 3   [English, Swedish, German, Arabic, Egyptian (A...
# 4                                           [English]
# ..                                                ...
# 65                                  [English, French]
# 66                                          [English]
# 67                                          [English]
# 68                                          [English]
# 69                                  [English, French]
#
#                                  production_companies  \
# 0   [Columbia Pictures, Bona Film Group, Heyday Fi...
# 1   [Paramount Pictures, Skydance Media, TC Produc...
# 2   [Lionsgate, Thunder Road Pictures, 87Eleven En...
# 3                         [Gaumont, Pinewood Studios]
# 4   [Warner Bros., Paramount Pictures, Legendary E...
# ..                                                ...
# 65      [Twentieth Century Fox, Hughes Entertainment]
# 66          [De Laurentiis Entertainment Group (DEG)]
# 67  [Castle Rock Entertainment, Nelson Entertainme...
# 68  [Touchstone Pictures, Universal Pictures, Stud...
# 69  [Columbia Pictures, Castle Rock Entertainment,...
#
#                          release_date  \
# 0       July 26, 2019 (United States)
# 1       July 12, 2023 (United States)
# 2      March 24, 2023 (United States)
# 3         May 9, 1997 (United States)
# 4       March 6, 2009 (United States)
# ..                                ...
# 65  November 16, 1990 (United States)
# 66           October 23, 1986 (Italy)
# 67      July 21, 1989 (United States)
# 68   February 2, 2001 (United States)
# 69  December 11, 1992 (United States)
#
#                                        comentarios_ia  \
# 0   [Authentic emotion positive sentiment, Charact...
# 1   [Action sequences positive sentiment, Sound de...
# 2   [Action sequences positive sentiment, Cinemato...
# 3                                                  []
# 4   [Ambitious positive sentiment, Cinematography ...
# ..                                                ...
# 65                                                 []
# 66                                                 []
# 67                                                 []
# 68                                                 []
# 69                                                 []
#
#                                            ai_summary duration_mins  \
# 0   Reviewers say 'Once Upon a Time in Hollywood' ...           161
# 1   Reviewers say 'Mission: Impossible - Dead Reck...           163
# 2   Reviewers say 'John Wick: Chapter 4' is lauded...           169
# 3                                                               126
# 4   Reviewers say 'Watchmen' is acclaimed for its ...           162
# ..                                                ...           ...
# 65                                                              103
# 66                                                              120
# 67                                                               95
# 68                                                              107
# 69                                                              138
#
#                         budget   gross_world gross_usa_canada  \
# 0      $90,000,000 (estimated)  $392,105,159     $142,502,728
# 1     $291,000,000 (estimated)  $571,125,435     $172,640,980
# 2     $100,000,000 (estimated)  $447,142,521     $187,131,806
# 3   FRF 75,210,000 (estimated)  $263,920,180      $63,820,180
# 4     $130,000,000 (estimated)  $185,382,813     $107,509,799
# ..                         ...           ...              ...
# 65     $18,000,000 (estimated)  $476,684,675     $285,761,243
# 66      $6,000,000 (estimated)    $8,675,306       $8,551,228
# 67     $16,000,000 (estimated)   $93,275,428      $93,117,425
# 68     $26,000,000 (estimated)   $71,877,090      $45,512,588
# 69     $41,000,000 (estimated)  $243,240,178     $141,340,178
#
#    opening_weekend_usa_canada
# 0     $41,082,018Jul 28, 2019
# 1     $54,688,347Jul 16, 2023
# 2     $73,817,950Mar 26, 2023
# 3     $17,031,345May 11, 1997
# 4      $55,214,334Mar 8, 2009
# ..                        ...
# 65    $17,081,997Nov 18, 1990
# 66       $789,409Sep 21, 1986
# 67     $1,094,453Jul 16, 1989
# 68       $195,104Dec 25, 2000
# 69    $15,517,468Dec 13, 1992
#
# [70 rows x 30 columns]

# %%
import re

def parse_money(value: str) -> float:
    if value is None:
        return None

    value = value.rstrip(" (estimated)")
    value = re.sub(r",", "", value)

    if value.startswith("$"):
        return float(value[1:])
    if value.startswith("FRF"):
        return float(value[4:]) * 0.17871603 # https://www.xe.com/currencyconverter/convert/?Amount=1&From=FRF&To=USD
    if value.startswith("€"):
        return float(value[1:]) * 1.1722995
    if value.startswith("DEM"):
        return float(value[4:]) * 0.59939338
    else:
        return None

def get_faltantes(cdf, original, target):
    return cdf[cdf[target].isna() & ~(cdf[original].isna())]

df["budget_usd"] = df["budget"].map(parse_money)
get_faltantes(df, "budget", "budget_usd")
# Out:
# Empty DataFrame
# Columns: [title, url, metacritic_score, rating, year, duration, rating_stars, voters, description, director, writers, stars, storyline, genres, genres_ext, awards_and_nominations, cast, box_office, aspect_ratio, countries, languages, production_companies, release_date, comentarios_ia, ai_summary, duration_mins, budget, gross_world, gross_usa_canada, opening_weekend_usa_canada, budget_usd]
# Index: []
#
# [0 rows x 31 columns]

# %%
df["gross_world_usd"] = df["gross_world"].map(parse_money)
get_faltantes(df, "gross_world", "gross_world_usd")
# Out:
# Empty DataFrame
# Columns: [title, url, metacritic_score, rating, year, duration, rating_stars, voters, description, director, writers, stars, storyline, genres, genres_ext, awards_and_nominations, cast, box_office, aspect_ratio, countries, languages, production_companies, release_date, comentarios_ia, ai_summary, duration_mins, budget, gross_world, gross_usa_canada, opening_weekend_usa_canada, budget_usd, gross_world_usd]
# Index: []
#
# [0 rows x 32 columns]

# %%
df["gross_usa_canada_usd"] = df["gross_usa_canada"].map(parse_money)
get_faltantes(df, "gross_usa_canada", "gross_usa_canada_usd")
# Out:
# Empty DataFrame
# Columns: [title, url, metacritic_score, rating, year, duration, rating_stars, voters, description, director, writers, stars, storyline, genres, genres_ext, awards_and_nominations, cast, box_office, aspect_ratio, countries, languages, production_companies, release_date, comentarios_ia, ai_summary, duration_mins, budget, gross_world, gross_usa_canada, opening_weekend_usa_canada, budget_usd, gross_world_usd, gross_usa_canada_usd]
# Index: []
#
# [0 rows x 33 columns]

# %%
def split_at_date(value: str) -> (str, str):
    idx = 0

    if value is None:
        return (None, None)

    while idx < len(value):
        try:
            if value[idx].isupper() and value[idx-1].isnumeric():
                return value[:idx], value[idx:]
        except IndexError:
            return value[:idx], value[idx:]

        idx += 1

# df["opening_weekend_usa_canada_usd"] = df["opening_weekend_usa_canada"].map(parse_money)
# get_faltantes(df, "opening_weekend_usa_canada", "opening_weekend_usa_canada_usd")

open_info = df["opening_weekend_usa_canada"].map(split_at_date)
df["opening_weekend_usa_canada_date"] = open_info.map(lambda x: x[1])
df["opening_weekend_usa_canada_usd"] = open_info.map(lambda x: parse_money(x[0]))

get_faltantes(df, "opening_weekend_usa_canada", "opening_weekend_usa_canada_usd")
# Out:
# Empty DataFrame
# Columns: [title, url, metacritic_score, rating, year, duration, rating_stars, voters, description, director, writers, stars, storyline, genres, genres_ext, awards_and_nominations, cast, box_office, aspect_ratio, countries, languages, production_companies, release_date, comentarios_ia, ai_summary, duration_mins, budget, gross_world, gross_usa_canada, opening_weekend_usa_canada, budget_usd, gross_world_usd, gross_usa_canada_usd, opening_weekend_usa_canada_date, opening_weekend_usa_canada_usd]
# Index: []
#
# [0 rows x 35 columns]

# %%
df.head()
# Out:
#                                            title  \
# 0               Once Upon a Time... in Hollywood
# 1  Mission: Impossible - Dead Reckoning Part One
# 2                           John Wick: Chapter 4
# 3                              The Fifth Element
# 4                                       Watchmen
#
#                                                  url metacritic_score rating  \
# 0  https://www.imdb.com/title/tt7131622/?ref_=sr_t_1               84      R
# 1  https://www.imdb.com/title/tt9603212/?ref_=sr_t_2               81  PG-13
# 2  https://www.imdb.com/title/tt10366206/?ref_=sr...               78      R
# 3  https://www.imdb.com/title/tt0119116/?ref_=sr_t_4               52  PG-13
# 4  https://www.imdb.com/title/tt0409459/?ref_=sr_t_5               56      R
#
#    year duration rating_stars   voters  \
# 0  2019   2h 41m          7.6   (930K)
# 1  2023   2h 43m          7.6   (313K)
# 2  2023   2h 49m          7.6   (394K)
# 3  1997    2h 6m          7.6   (534K)
# 4  2009   2h 42m          7.6   (604K)
#
#                                          description                 director  \
# 0  As Hollywood's Golden Age is winding down duri...      [Quentin Tarantino]
# 1  Ethan Hunt and his IMF team must track down a ...  [Christopher McQuarrie]
# 2  John Wick uncovers a path to defeating The Hig...         [Chad Stahelski]
# 3  In the colorful future, cabdriver Korben Dalla...             [Luc Besson]
# 4  In a version of 1985 where superheroes exist, ...            [Zack Snyder]
#
#    ... duration_mins                      budget   gross_world  \
# 0  ...           161     $90,000,000 (estimated)  $392,105,159
# 1  ...           163    $291,000,000 (estimated)  $571,125,435
# 2  ...           169    $100,000,000 (estimated)  $447,142,521
# 3  ...           126  FRF 75,210,000 (estimated)  $263,920,180
# 4  ...           162    $130,000,000 (estimated)  $185,382,813
#
#   gross_usa_canada opening_weekend_usa_canada    budget_usd gross_world_usd  \
# 0     $142,502,728    $41,082,018Jul 28, 2019  9.000000e+07     392105159.0
# 1     $172,640,980    $54,688,347Jul 16, 2023  2.910000e+08     571125435.0
# 2     $187,131,806    $73,817,950Mar 26, 2023  1.000000e+08     447142521.0
# 3      $63,820,180    $17,031,345May 11, 1997  1.344123e+07     263920180.0
# 4     $107,509,799     $55,214,334Mar 8, 2009  1.300000e+08     185382813.0
#
#   gross_usa_canada_usd opening_weekend_usa_canada_date  \
# 0          142502728.0                    Jul 28, 2019
# 1          172640980.0                    Jul 16, 2023
# 2          187131806.0                    Mar 26, 2023
# 3           63820180.0                    May 11, 1997
# 4          107509799.0                     Mar 8, 2009
#
#   opening_weekend_usa_canada_usd
# 0                     41082018.0
# 1                     54688347.0
# 2                     73817950.0
# 3                     17031345.0
# 4                     55214334.0
#
# [5 rows x 35 columns]

# %%
def parse_awards(value: str) -> (int, int):
    words = value.split(" ")
    nominations = 0
    awards = 0

    for idx, word in enumerate(words):
        if word.startswith("win"):
            awards = int(words[idx-1])
        elif word.startswith("nomina"):
            nominations = int(words[idx-1])

    return awards, nominations

df["awards"] = df["awards_and_nominations"].map(lambda x: parse_awards(x)[0])
df["nominations"] = df["awards_and_nominations"].map(lambda x: parse_awards(x)[1])

df[["awards_and_nominations", "awards", "nominations"]].head()
# Out:
#              awards_and_nominations  awards  nominations
# 0  146 wins & 377 nominations total     146          377
# 1    18 wins & 68 nominations total      18           68
# 2    38 wins & 51 nominations total      38           51
# 3    10 wins & 39 nominations total      10           39
# 4    12 wins & 24 nominations total      12           24

# %%
df["voters_int"] = df["voters"].replace(r"\(|\)| ", "", regex=True).replace("K", "000", regex=True).replace("M", "000000", regex=True).astype("int")

df[["voters", "voters_int"]].head()
# Out:
#     voters  voters_int
# 0   (930K)      930000
# 1   (313K)      313000
# 2   (394K)      394000
# 3   (534K)      534000
# 4   (604K)      604000

# %%
df["rating_stars_int"] = df["rating_stars"].astype("float")
df[["rating_stars", "rating_stars_int"]].head()
# Out:
#   rating_stars  rating_stars_int
# 0          7.6               7.6
# 1          7.6               7.6
# 2          7.6               7.6
# 3          7.6               7.6
# 4          7.6               7.6

# %%
df.to_parquet(utils.find_project_root() / "data" / "inter" / "stage2.parquet")
