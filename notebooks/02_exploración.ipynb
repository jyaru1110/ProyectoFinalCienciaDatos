# %%
import pandas as pd
from common import utils

# %%
df = pd.read_parquet(utils.find_project_root() / "data" / "inter" / "stage2.parquet")
df
# Out:
#                                             title  \
# 0                Once Upon a Time... in Hollywood
# 1   Mission: Impossible - Dead Reckoning Part One
# 2                            John Wick: Chapter 4
# 3                               The Fifth Element
# 4                                        Watchmen
# ..                                            ...
# 65                                     Home Alone
# 66                                    Blue Velvet
# 67                        When Harry Met Sally...
# 68                     O Brother, Where Art Thou?
# 69                                 A Few Good Men
#
#                                                   url rating  \
# 0   https://www.imdb.com/title/tt7131622/?ref_=sr_t_1      R
# 1   https://www.imdb.com/title/tt9603212/?ref_=sr_t_2  PG-13
# 2   https://www.imdb.com/title/tt10366206/?ref_=sr...      R
# 3   https://www.imdb.com/title/tt0119116/?ref_=sr_t_4  PG-13
# ...
